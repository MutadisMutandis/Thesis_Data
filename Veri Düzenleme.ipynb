# %%
import openpyxl as xl
import numpy as np
import pandas as pd

# %%
names = ["2009", "2010", "2011", "2012","2013",
         "2014", "2015", "2016", "2017","2018",
         "2019", "2020"]

# %%
for name in names:
    wb = xl.load_workbook("Kurumsal Sektör Hesapları" + " " + name +".xlsx")
    sheet = wb["t_"+ name]
    
    wb1 = "Kurumsal Sektör Hesapları" + " " + name +".xlsx"
    sheet1 = "t_"+ name
    
    print(wb1, "-----", sheet1)
    
    cols = ["Mali Olmayan Şİrketler", "Mali Şirketler", 
                             "Genel Devlet", "Hanehalkı-Hizmet", 
                             "Toplam Ekonomi", "Dış Alem", 
                             "Sektörler Toplamı"]

    df = pd.DataFrame(columns = cols + cols)
    source_use_cels = ["J", "K", "L", "M", "N", "O", "P","G", "F", "E", "D", "C", "B", "A"]
    rng = [range(6,16),range(17,26),range(30,46),range(47,59),
       range(63,69),range(70,79),range(82,88),range(89,97),]

    for x in rng:

        for r in x:
            liste = []

            row_value = sheet["I" + str(r)].value
            if row_value in df.index:
                row_value = row_value + "_" + str(r)

            for c in source_use_cels:
                value = sheet[c + str(r)].value
                liste.append(value)

            df.loc[row_value] = liste
            
    df.to_excel("KSH_" + name + ".xlsx")
# Out:
# Kurumsal Sektör Hesapları 2009.xlsx ----- t_2009
# Kurumsal Sektör Hesapları 2010.xlsx ----- t_2010
# Kurumsal Sektör Hesapları 2011.xlsx ----- t_2011
# Kurumsal Sektör Hesapları 2012.xlsx ----- t_2012
# Kurumsal Sektör Hesapları 2013.xlsx ----- t_2013
# Kurumsal Sektör Hesapları 2014.xlsx ----- t_2014
# Kurumsal Sektör Hesapları 2015.xlsx ----- t_2015
# Kurumsal Sektör Hesapları 2016.xlsx ----- t_2016
# Kurumsal Sektör Hesapları 2017.xlsx ----- t_2017
# Kurumsal Sektör Hesapları 2018.xlsx ----- t_2018
# Kurumsal Sektör Hesapları 2019.xlsx ----- t_2019
# Kurumsal Sektör Hesapları 2020.xlsx ----- t_2020

# %% [markdown]
# ### Üretim Hesabı

# %%
cols = ["Mali Olmayan Şİrketler", "Mali Şirketler", 
                             "Genel Devlet", "Hanehalkı-Hizmet", 
                             "Toplam Ekonomi", "Dış Alem", 
                             "Sektörler Toplamı"]

df = pd.DataFrame(columns = cols + cols)
df
# Out:
# Empty DataFrame
# Columns: [Mali Olmayan Şİrketler, Mali Şirketler, Genel Devlet, Hanehalkı-Hizmet, Toplam Ekonomi, Dış Alem, Sektörler Toplamı, Mali Olmayan Şİrketler, Mali Şirketler, Genel Devlet, Hanehalkı-Hizmet, Toplam Ekonomi, Dış Alem, Sektörler Toplamı]
# Index: []

# %%
source_use_cels = ["J", "K", "L", "M", "N", "O", "P","G", "F", "E", "D", "C", "B", "A"]
rng = [range(6,16),range(17,26),range(30,46),range(47,59),
       range(63,69),range(70,79),range(82,88),range(89,97),]

for x in rng:

    for r in x:
        liste = []

        row_value = sheet["I" + str(r)].value
        if row_value in df.index:
            row_value = row_value + "_" + str(r)

        for c in source_use_cels:
            value = sheet[c + str(r)].value
            liste.append(value)

        df.loc[row_value] = liste

# %%
df.head()
# Out:
#                                                    Mali Olmayan Şİrketler  \
# Çıktı - Output                                          1227772022.557403
# Piyasa çıktısı - Market output                           1220355932.97406
# Kendi nihai tüketimi için çıktı - Output for ow...         7416089.583343
# Piyasa-dışı çıktı - Non-market output                                 0.0
# Ara tüketim - Intermediate consumption                                0.0
#
#                                                      Mali Şirketler  \
# Çıktı - Output                                      56187139.223201
# Piyasa çıktısı - Market output                      55942190.407379
# Kendi nihai tüketimi için çıktı - Output for ow...    244948.815822
# Piyasa-dışı çıktı - Non-market output                           NaN
# Ara tüketim - Intermediate consumption                          0.0
#
#                                                     Genel Devlet  \
# Çıktı - Output                                      1.532667e+08
# Piyasa çıktısı - Market output                      5.873319e+06
# Kendi nihai tüketimi için çıktı - Output for ow...  4.008757e+06
# Piyasa-dışı çıktı - Non-market output               1.433846e+08
# Ara tüketim - Intermediate consumption              0.000000e+00
#
#                                                     Hanehalkı-Hizmet  \
# Çıktı - Output                                       369034065.96733
# Piyasa çıktısı - Market output                      292830137.214755
# Kendi nihai tüketimi için çıktı - Output for ow...   72824017.670885
# Piyasa-dışı çıktı - Non-market output                  3379911.08169
# Ara tüketim - Intermediate consumption                           0.0
#
#                                                     Toplam Ekonomi  Dış Alem  \
# Çıktı - Output                                        1.806260e+09       0.0
# Piyasa çıktısı - Market output                        1.575002e+09       0.0
# Kendi nihai tüketimi için çıktı - Output for ow...    8.449381e+07       0.0
# Piyasa-dışı çıktı - Non-market output                 1.467646e+08       0.0
# Ara tüketim - Intermediate consumption                0.000000e+00       0.0
#
#                                                     Sektörler Toplamı  \
# Çıktı - Output                                                    0.0
# Piyasa çıktısı - Market output                                    0.0
# Kendi nihai tüketimi için çıktı - Output for ow...                0.0
# Piyasa-dışı çıktı - Non-market output                             0.0
# Ara tüketim - Intermediate consumption                            0.0
#
#                                                    Mali Olmayan Şİrketler  \
# Çıktı - Output                                                        0.0
# Piyasa çıktısı - Market output                                        0.0
# Kendi nihai tüketimi için çıktı - Output for ow...                    0.0
# Piyasa-dışı çıktı - Non-market output                                 0.0
# Ara tüketim - Intermediate consumption                   759584062.752681
#
#                                                      Mali Şirketler  \
# Çıktı - Output                                                  0.0
# Piyasa çıktısı - Market output                                  0.0
# Kendi nihai tüketimi için çıktı - Output for ow...              0.0
# Piyasa-dışı çıktı - Non-market output                           0.0
# Ara tüketim - Intermediate consumption              18715488.019781
#
#                                                     Genel Devlet  \
# Çıktı - Output                                      0.000000e+00
# Piyasa çıktısı - Market output                      0.000000e+00
# Kendi nihai tüketimi için çıktı - Output for ow...  0.000000e+00
# Piyasa-dışı çıktı - Non-market output               0.000000e+00
# Ara tüketim - Intermediate consumption              4.507864e+07
#
#                                                    Hanehalkı-Hizmet  \
# Çıktı - Output                                                  0.0
# Piyasa çıktısı - Market output                                  0.0
# Kendi nihai tüketimi için çıktı - Output for ow...              0.0
# Piyasa-dışı çıktı - Non-market output                           0.0
# Ara tüketim - Intermediate consumption              84618686.462192
#
#                                                     Toplam Ekonomi  Dış Alem  \
# Çıktı - Output                                        0.000000e+00       0.0
# Piyasa çıktısı - Market output                        0.000000e+00       0.0
# Kendi nihai tüketimi için çıktı - Output for ow...    0.000000e+00       0.0
# Piyasa-dışı çıktı - Non-market output                 0.000000e+00       0.0
# Ara tüketim - Intermediate consumption                9.079969e+08       0.0
#
#                                                     Sektörler Toplamı
# Çıktı - Output                                                    0.0
# Piyasa çıktısı - Market output                                    0.0
# Kendi nihai tüketimi için çıktı - Output for ow...                0.0
# Piyasa-dışı çıktı - Non-market output                             0.0
# Ara tüketim - Intermediate consumption                            0.0

# %%
df
# Out:
#                                                    Mali Olmayan Şİrketler  \
# Çıktı - Output                                          1227772022.557403
# Piyasa çıktısı - Market output                           1220355932.97406
# Kendi nihai tüketimi için çıktı - Output for ow...         7416089.583343
# Piyasa-dışı çıktı - Non-market output                                 0.0
# Ara tüketim - Intermediate consumption                                0.0
# ...                                                                   ...
# Sabit sermaye oluşumu - Gross capital formation                       0.0
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...                    0.0
# Envanterlerdeki değişmeler - Changes in invento...                    0.0
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...                    0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...                    0.0
#
#                                                      Mali Şirketler  \
# Çıktı - Output                                      56187139.223201
# Piyasa çıktısı - Market output                      55942190.407379
# Kendi nihai tüketimi için çıktı - Output for ow...    244948.815822
# Piyasa-dışı çıktı - Non-market output                           NaN
# Ara tüketim - Intermediate consumption                          0.0
# ...                                                             ...
# Sabit sermaye oluşumu - Gross capital formation                 0.0
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...              0.0
# Envanterlerdeki değişmeler - Changes in invento...              0.0
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...              0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...              0.0
#
#                                                     Genel Devlet  \
# Çıktı - Output                                      1.532667e+08
# Piyasa çıktısı - Market output                      5.873319e+06
# Kendi nihai tüketimi için çıktı - Output for ow...  4.008757e+06
# Piyasa-dışı çıktı - Non-market output               1.433846e+08
# Ara tüketim - Intermediate consumption              0.000000e+00
# ...                                                          ...
# Sabit sermaye oluşumu - Gross capital formation     0.000000e+00
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...  0.000000e+00
# Envanterlerdeki değişmeler - Changes in invento...  0.000000e+00
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...  0.000000e+00
# Üretilmemiş mali olmayan varlıkların edinimi ek...  0.000000e+00
#
#                                                     Hanehalkı-Hizmet  \
# Çıktı - Output                                       369034065.96733
# Piyasa çıktısı - Market output                      292830137.214755
# Kendi nihai tüketimi için çıktı - Output for ow...   72824017.670885
# Piyasa-dışı çıktı - Non-market output                  3379911.08169
# Ara tüketim - Intermediate consumption                           0.0
# ...                                                              ...
# Sabit sermaye oluşumu - Gross capital formation                  0.0
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...               0.0
# Envanterlerdeki değişmeler - Changes in invento...               0.0
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...               0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...               0.0
#
#                                                     Toplam Ekonomi  Dış Alem  \
# Çıktı - Output                                        1.806260e+09       0.0
# Piyasa çıktısı - Market output                        1.575002e+09       0.0
# Kendi nihai tüketimi için çıktı - Output for ow...    8.449381e+07       0.0
# Piyasa-dışı çıktı - Non-market output                 1.467646e+08       0.0
# Ara tüketim - Intermediate consumption                0.000000e+00       0.0
# ...                                                            ...       ...
# Sabit sermaye oluşumu - Gross capital formation       0.000000e+00       0.0
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...    0.000000e+00       0.0
# Envanterlerdeki değişmeler - Changes in invento...    0.000000e+00       0.0
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...    0.000000e+00       0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...    0.000000e+00       0.0
#
#                                                     Sektörler Toplamı  \
# Çıktı - Output                                                    0.0
# Piyasa çıktısı - Market output                                    0.0
# Kendi nihai tüketimi için çıktı - Output for ow...                0.0
# Piyasa-dışı çıktı - Non-market output                             0.0
# Ara tüketim - Intermediate consumption                            0.0
# ...                                                               ...
# Sabit sermaye oluşumu - Gross capital formation                   0.0
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...                0.0
# Envanterlerdeki değişmeler - Changes in invento...                0.0
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...                0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...                0.0
#
#                                                    Mali Olmayan Şİrketler  \
# Çıktı - Output                                                        0.0
# Piyasa çıktısı - Market output                                        0.0
# Kendi nihai tüketimi için çıktı - Output for ow...                    0.0
# Piyasa-dışı çıktı - Non-market output                                 0.0
# Ara tüketim - Intermediate consumption                   759584062.752681
# ...                                                                   ...
# Sabit sermaye oluşumu - Gross capital formation          127837044.531219
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...        121061455.81436
# Envanterlerdeki değişmeler - Changes in invento...         6775588.716859
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...                    0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...         1691115.223108
#
#                                                      Mali Şirketler  \
# Çıktı - Output                                                  0.0
# Piyasa çıktısı - Market output                                  0.0
# Kendi nihai tüketimi için çıktı - Output for ow...              0.0
# Piyasa-dışı çıktı - Non-market output                           0.0
# Ara tüketim - Intermediate consumption              18715488.019781
# ...                                                             ...
# Sabit sermaye oluşumu - Gross capital formation      4258151.791376
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...   4258151.791376
# Envanterlerdeki değişmeler - Changes in invento...              0.0
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...              0.0
# Üretilmemiş mali olmayan varlıkların edinimi ek...              0.0
#
#                                                     Genel Devlet  \
# Çıktı - Output                                      0.000000e+00
# Piyasa çıktısı - Market output                      0.000000e+00
# Kendi nihai tüketimi için çıktı - Output for ow...  0.000000e+00
# Piyasa-dışı çıktı - Non-market output               0.000000e+00
# Ara tüketim - Intermediate consumption              4.507864e+07
# ...                                                          ...
# Sabit sermaye oluşumu - Gross capital formation     3.799662e+07
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...  3.846253e+07
# Envanterlerdeki değişmeler - Changes in invento... -4.705080e+05
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...  4.594766e+03
# Üretilmemiş mali olmayan varlıkların edinimi ek...  3.167498e+06
#
#                                                    Hanehalkı-Hizmet  \
# Çıktı - Output                                                  0.0
# Piyasa çıktısı - Market output                                  0.0
# Kendi nihai tüketimi için çıktı - Output for ow...              0.0
# Piyasa-dışı çıktı - Non-market output                           0.0
# Ara tüketim - Intermediate consumption              84618686.462192
# ...                                                             ...
# Sabit sermaye oluşumu - Gross capital formation     59525597.255729
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...  56171409.994664
# Envanterlerdeki değişmeler - Changes in invento...   -398276.165468
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...   3752463.426533
# Üretilmemiş mali olmayan varlıkların edinimi ek...   -4794582.41634
#
#                                                     Toplam Ekonomi  \
# Çıktı - Output                                        0.000000e+00
# Piyasa çıktısı - Market output                        0.000000e+00
# Kendi nihai tüketimi için çıktı - Output for ow...    0.000000e+00
# Piyasa-dışı çıktı - Non-market output                 0.000000e+00
# Ara tüketim - Intermediate consumption                9.079969e+08
# ...                                                            ...
# Sabit sermaye oluşumu - Gross capital formation       2.296174e+08
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...    2.199535e+08
# Envanterlerdeki değişmeler - Changes in invento...    5.906805e+06
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...    3.757058e+06
# Üretilmemiş mali olmayan varlıkların edinimi ek...    6.403127e+04
#
#                                                         Dış Alem  \
# Çıktı - Output                                          0.000000
# Piyasa çıktısı - Market output                          0.000000
# Kendi nihai tüketimi için çıktı - Output for ow...      0.000000
# Piyasa-dışı çıktı - Non-market output                   0.000000
# Ara tüketim - Intermediate consumption                  0.000000
# ...                                                          ...
# Sabit sermaye oluşumu - Gross capital formation         0.000000
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...      0.000000
# Envanterlerdeki değişmeler - Changes in invento...      0.000000
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...      0.000000
# Üretilmemiş mali olmayan varlıkların edinimi ek... -64031.272188
#
#                                                     Sektörler Toplamı
# Çıktı - Output                                           0.000000e+00
# Piyasa çıktısı - Market output                           0.000000e+00
# Kendi nihai tüketimi için çıktı - Output for ow...       0.000000e+00
# Piyasa-dışı çıktı - Non-market output                    0.000000e+00
# Ara tüketim - Intermediate consumption                   0.000000e+00
# ...                                                               ...
# Sabit sermaye oluşumu - Gross capital formation          0.000000e+00
# Gayrisafi sabit sermaye oluşumu - Gross fixed c...       0.000000e+00
# Envanterlerdeki değişmeler - Changes in invento...       0.000000e+00
# Değerlilerin edinimi eksi elden çıkarılışı - Ac...       0.000000e+00
# Üretilmemiş mali olmayan varlıkların edinimi ek...       1.527951e-10
#
# [65 rows x 14 columns]

# %%
wb = xl.load_workbook("Kurumsal Sektör Hesapları 2020.xlsx")
sheet = wb["t_2020"]
value = sheet["G96"].value
value
# Out:
# -190611991.7433476

# %%
value+1
# Out:
# -190611990.7433476

# %%
df
# Out:
#                                                     Mali Olmayan Şİrketler  \
# Çıktı - Output                                                1.227772e+09
# Piyasa çıktısı - Market output                                1.220356e+09
# Kendi nihai tüketimi için çıktı - Output for ow...            7.416090e+06
# Piyasa-dışı çıktı - Non-market output                         0.000000e+00
#
#                                                     Mali Şirketler  \
# Çıktı - Output                                        5.618714e+07
# Piyasa çıktısı - Market output                        5.594219e+07
# Kendi nihai tüketimi için çıktı - Output for ow...    2.449488e+05
# Piyasa-dışı çıktı - Non-market output                          NaN
#
#                                                     Genel Devlet  \
# Çıktı - Output                                      1.532667e+08
# Piyasa çıktısı - Market output                      5.873319e+06
# Kendi nihai tüketimi için çıktı - Output for ow...  4.008757e+06
# Piyasa-dışı çıktı - Non-market output               1.433846e+08
#
#                                                     Hanehalkı-Hizmet  \
# Çıktı - Output                                          3.690341e+08
# Piyasa çıktısı - Market output                          2.928301e+08
# Kendi nihai tüketimi için çıktı - Output for ow...      7.282402e+07
# Piyasa-dışı çıktı - Non-market output                   3.379911e+06
#
#                                                     Toplam Ekonomi  Dış Alem  \
# Çıktı - Output                                        1.806260e+09       0.0
# Piyasa çıktısı - Market output                        1.575002e+09       0.0
# Kendi nihai tüketimi için çıktı - Output for ow...    8.449381e+07       0.0
# Piyasa-dışı çıktı - Non-market output                 1.467646e+08       0.0
#
#                                                     Sektörler Toplamı
# Çıktı - Output                                                    0.0
# Piyasa çıktısı - Market output                                    0.0
# Kendi nihai tüketimi için çıktı - Output for ow...                0.0
# Piyasa-dışı çıktı - Non-market output                             0.0

# %%
df.loc["Merhaba"] = ["asdf","asdf","asdf","asdf","asdf","asdf","asdf"]

# %%
df
# Out:
#         Mali Olmayan Şİrketler Mali Şirketler Genel Devlet Hanehalkı-Hizmet  \
# Merhaba                   asdf           asdf         asdf             asdf
#
#         Toplam Ekonomi Dış Alem Sektörler Toplamı
# Merhaba           asdf     asdf              asdf

# %%
# Out:
# 'Mal ihracatı - Exports of goods'
